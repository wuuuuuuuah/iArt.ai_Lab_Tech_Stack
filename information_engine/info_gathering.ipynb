# %%
with open('../../my_key.txt') as f:
    key_list = f.readlines()

key_list = [key.strip() for key in key_list]

keys = {}
for key in key_list:
    key = key.split(':')
    if (key != ['']):
        keys[key[0]] = key[1]

# %%
import os
os.environ["GOOGLE_CSE_ID"] = keys['GOOGLE_CSE_ID']
os.environ["GOOGLE_API_KEY"] = keys['GOOGLE_API_KEY']

# %% [markdown]
# # Information Gathering
# - Objectives
#     - Gather Information From Web
# - I/O
#     - Input: Query
#     - Output: Text relative to give anwser
# - Features
#     - All Web Search
#         - Only in Google Programmable Search Engine's Setting can we config Search Range
#     - Domain Search
#         - Only search in some specific domain

# %% [markdown]
# ## 1. Query Construction

# %%
query = "Why Elon Musk bought twitter?"

# %%
# query = f"site:youtube.com search:{query}"  # Good
# query = f"site:arxiv.org/pdf search:{query}"  # Good
# query = f"site:arxiv.org search:{query}"  # Good
# query = f"site:arxiv.org/abs search:{query}"  # Good
# query = f"site:scholar.google.com search:{query}"  # Need Process
# query = f"site:wikipedia.org search:{query}"  # Good
# query = f"site:news.google.com search:{query}"  # Good
# query = f"site:news.google.com OR site:cnn.com search:{query}"  # Not Good enough
query_c = f"search:{query}"  # Good

# %% [markdown]
# ## 2. Search
# - I/O
#     - Input: Query
#     - Output: {"Link", "Title", "Snippet"}
# - Performance
#     - Runtime: Less than 2s

# %% [markdown]
# ### Google Custom Search Engine
# - Method:
#     - Google Official Python API
#     - Langchain - GoogleSearchAPIWrapper
# - Problem

# %% [markdown]
# #### Google Official API

# %%
# Build a Google Search Service
from googleapiclient.discovery import build

service = build(
    "customsearch", "v1",
    developerKey=os.environ["GOOGLE_API_KEY"]
)

# %%
# Get Search Result
search_result = service.cse().list(
    q = query_c,
    cx = os.environ["GOOGLE_CSE_ID"]
).execute()

# %%
search_result
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - search:Why Elon Musk bought twitter?',
#     'totalResults': '55100000',
#     'searchTerms': 'search:Why Elon Musk bought twitter?',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '75c110d49120f4364'}],
#   'nextPage': [{'title': 'Google Custom Search - search:Why Elon Musk bought twitter?',
#     'totalResults': '55100000',
#     'searchTerms': 'search:Why Elon Musk bought twitter?',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '75c110d49120f4364'}]},
#  'context': {'title': 'Google Search'},
#  'searchInformation': {'searchTime': 0.317942,
#   'formattedSearchTime': '0.32',
#   'totalResults': '55100000',
#   'formattedTotalResults': '55,100,000'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Acquisition of Twitter by Elon Musk - Wikipedia',
#    'htmlTitle': 'Acquisition of <b>Twitter</b> by <b>Elon Musk</b> - Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/Acquisition_of_Twitter_by_Elon_Musk',
#    'displayLink': 'en.wikipedia.org',
#    'snippet': 'Musk had begun buying shares of the company in January 2022, becoming its largest shareholder by April with a 9.1 percent ownership stake. Twitter invited\xa0...',
#    'htmlSnippet': '<b>Musk</b> had begun <b>buying</b> shares of the company in January 2022, becoming its largest shareholder by April with a 9.1 percent ownership stake. <b>Twitter</b> invited&nbsp;...',
#    'cacheId': 'WGa85lU1gD4J',
#    'formattedUrl': 'https://en.wikipedia.org/wiki/Acquisition_of_Twitter_by_Elon_Musk',
#    'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Acquisition_of_<b>Twitter</b>_by_<b>Elon</b>_<b>Musk</b>',
#    'pagemap': {'hcard': [{'fn': 'Acquisition of Twitter by Elon Musk'}],
#     'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTzmLcKKDZUbDoG5lTDPNaR6SJ0LZ2_TLREhs5AVl1xll0FUpvmt2_AGgQ',
#       'width': '170',
#       'height': '212'}],
#     'metatags': [{'referrer': 'origin',
#       'theme-color': '#eaecf0',
#       'og:type': 'website',
#       'viewport': 'width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.25, maximum-scale=5.0',
#       'og:title': 'Acquisition of Twitter by Elon Musk - Wikipedia',
#       'format-detection': 'telephone=no'}],
#     'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Peiter_Zatko_at_DARPA.jpg/170px-Peiter_Zatko_at_DARPA.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Hate Speech's Rise on Twitter Under Elon Musk Is Unprecedented ...",
#    'htmlTitle': 'Hate Speech&#39;s Rise on <b>Twitter</b> Under <b>Elon Musk</b> Is Unprecedented ...',
#    'link': 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html',
#    'displayLink': 'www.nytimes.com',
#    'snippet': "Dec 2, 2022 ... Hate Speech's Rise on Twitter Is Unprecedented, Researchers Find ... Before Elon Musk bought Twitter, slurs against Black Americans showed\xa0...",
#    'htmlSnippet': 'Dec 2, 2022 <b>...</b> Hate Speech&#39;s Rise on <b>Twitter</b> Is Unprecedented, Researchers <b>Find</b> ... Before <b>Elon Musk bought Twitter</b>, slurs against Black Americans showed&nbsp;...',
#    'formattedUrl': 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html',
#    'htmlFormattedUrl': 'https://www.nytimes.com/2022/12/02/technology/<b>twitter</b>-hate-speech.html',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQ0IlYZqqqQhD3MyUv7m9y8dmlR6fU2e41rLAdfqoDFVYPZ2nJ9vWpifVg',
#       'width': '310',
#       'height': '162'}],
#     'metatags': [{'og:image': 'https://static01.nyt.com/images/2022/12/02/multimedia/02twitter-misinfo-1-9f04/02twitter-misinfo-1-9f04-facebookJumbo.jpg',
#       'nyt_uri': 'nyt://article/e9d0690b-2ee5-5a9d-8ce2-2a2dced92214',
#       'twitter:app:id:googleplay': 'com.nytimes.android',
#       'twitter:card': 'summary_large_image',
#       'article:published_time': '2022-12-02T14:00:13.000Z',
#       'pt': 'article',
#       'twitter:url': 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html',
#       'pdate': '20221202',
#       'articleid': '100000008664976',
#       'al:android:package': 'com.nytimes.android',
#       'twitter:app:name:googleplay': 'NYTimes',
#       'og:description': 'Problematic content and formerly barred accounts have increased sharply in the short time since Elon Musk took over, researchers said.',
#       'twitter:image': 'https://static01.nyt.com/images/2022/12/02/multimedia/02twitter-misinfo-1-9f04/02twitter-misinfo-1-9f04-videoSixteenByNine3000.jpg',
#       'pst': 'News',
#       'twitter:image:alt': 'Elon Musk, who took over Twitter in October, has described himself as a “free speech absolutist.”',
#       'article:modified_time': '2022-12-02T19:16:05.000Z',
#       'news_keywords': ',Hate Speech,Discrimination,Social Media,Computers and the Internet,Tech Industry,Elon Musk,Black People;African American;African-American,Women and Girls,Race and Ethnicity,Antisemitism,Censorship,Corporate Social Responsibility,Rumors and Misinformation,advertising;marketing,Anti Defamation League',
#       'article:content_tier': 'metered',
#       'msapplication-starturl': 'https://www.nytimes.com',
#       'image': 'https://static01.nyt.com/images/2022/12/02/multimedia/02twitter-misinfo-1-9f04/02twitter-misinfo-1-9f04-facebookJumbo.jpg',
#       'og:type': 'article',
#       'og:image:alt': 'Elon Musk, who took over Twitter in October, has described himself as a “free speech absolutist.”',
#       'twitter:title': 'Hate Speech’s Rise on Twitter Is Unprecedented, Researchers Find',
#       'article:section': 'Technology',
#       'cg': 'technology',
#       'pubp_event_id': 'pubp://event/4f2886f87e324d81be12103951426796',
#       'og:title': 'Hate Speech’s Rise on Twitter Is Unprecedented, Researchers Find',
#       'url': 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html',
#       'article:tag': 'Twitter',
#       'al:android:url': 'nyt://article/e9d0690b-2ee5-5a9d-8ce2-2a2dced92214',
#       'twitter:app:url:googleplay': 'nyt://article/e9d0690b-2ee5-5a9d-8ce2-2a2dced92214',
#       'byl': 'By Sheera Frenkel and Kate Conger',
#       'twitter:description': 'Problematic content and formerly barred accounts have increased sharply in the short time since Elon Musk took over, researchers said.',
#       'og:url': 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html',
#       'al:android:app_name': 'NYTimes',
#       'article:opinion': 'false'}],
#     'cse_image': [{'src': 'https://static01.nyt.com/images/2022/12/02/multimedia/02twitter-misinfo-1-9f04/02twitter-misinfo-1-9f04-facebookJumbo.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Why Elon Musk Bought Twitter | The New Yorker',
#    'htmlTitle': 'Why <b>Elon Musk Bought Twitter</b> | The New Yorker',
#    'link': 'https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter',
#    'displayLink': 'www.newyorker.com',
#    'snippet': "Apr 26, 2022 ... Why do you think Elon Musk is buying Twitter? I assume it's because he has some genuine set of political and social beliefs about how Twitter\xa0...",
#    'htmlSnippet': 'Apr 26, 2022 <b>...</b> Why do you think <b>Elon Musk</b> is <b>buying Twitter</b>? I assume it&#39;s because he has some genuine set of political and social beliefs about how <b>Twitter</b>&nbsp;...',
#    'formattedUrl': 'https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter',
#    'htmlFormattedUrl': 'https://www.newyorker.com/news/q-and-a/why-<b>elon</b>-<b>musk</b>-<b>bought</b>-<b>twitter</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSRZQbKTbUsRjlXWTAQ4_3jljWllLtwY3qwCv01kPdsNymV7quiUgxH67jn',
#       'width': '300',
#       'height': '168'}],
#     'metatags': [{'og:image': 'https://media.newyorker.com/photos/6268189cdcb129a86fd41a80/16:9/w_1280,c_limit/Chotiner-Musk.jpg',
#       'copyright': 'Copyright (c) Condé Nast 2023',
#       'article:published_time': '2022-04-26T16:54:34.834Z',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'The New Yorker',
#       'parsely-metadata': '{"description":"The social network’s freewheeling poster child will pay forty-four billion dollars to take it private. What does he have in store?","image-16-9":"https://media.newyorker.com/photos/6268189cdcb129a86fd41a80/16:9/w_1000,c_limit/Chotiner-Musk.jpg","image-1-1":"https://media.newyorker.com/photos/6268189cdcb129a86fd41a80/1:1/w_1000,c_limit/Chotiner-Musk.jpg"}',
#       'og:description': 'The social network’s freewheeling poster child will pay forty-four billion dollars to take it private. What does he have in store?',
#       'twitter:creator': '@NewYorker',
#       'twitter:image': 'https://media.newyorker.com/photos/6268189cdcb129a86fd41a80/16:9/w_1280,c_limit/Chotiner-Musk.jpg?mbid=social_retweet',
#       'msapplication-tap-highlight': 'no',
#       'twitter:site': '@NewYorker',
#       'article:modified_time': '2022-04-26T16:54:34.834Z',
#       'news_keywords': 'elon musk,social media,finance,twitter,business,technology,disable inline signup unit',
#       'content-type': 'article',
#       'article:content_tier': 'free',
#       'id': '626769c6acfb56062917af16',
#       'og:type': 'article',
#       'article:section': 'tags',
#       'twitter:title': 'Why Elon Musk Bought Twitter',
#       'parsely-post-id': '626769c6acfb56062917af16',
#       'twitter:domain': 'https://www.newyorker.com',
#       'author': 'Condé Nast',
#       'og:title': 'Why Elon Musk Bought Twitter',
#       'fb:pages': '9258148868',
#       'article:author': 'Isaac Chotiner',
#       'referrer': 'no-referrer-when-downgrade',
#       'fb:app_id': '1147169538698836',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': 'The social network’s freewheeling poster child will pay forty-four billion dollars to take it private. What does he have in store?',
#       'og:url': 'https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter',
#       'google-signin-client_id': '275906274807-b4eqbdqr511u9msdpj8mh0pf77fcciv7.apps.googleusercontent.com',
#       'article:opinion': 'false'}],
#     'cse_image': [{'src': 'https://media.newyorker.com/photos/6268189cdcb129a86fd41a80/16:9/w_1280,c_limit/Chotiner-Musk.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Elon Musk - Wikipedia',
#    'htmlTitle': '<b>Elon Musk</b> - Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/Elon_Musk',
#    'displayLink': 'en.wikipedia.org',
#    'snippet': 'Elon Reeve Musk is a business magnate and investor. He is the founder, CEO and chief ... Musk expressed interest in buying Twitter as early as 2017,\xa0...',
#    'htmlSnippet': '<b>Elon</b> Reeve <b>Musk</b> is a business magnate and investor. He is the founder, CEO and chief ... <b>Musk</b> expressed interest in <b>buying Twitter</b> as early as 2017,&nbsp;...',
#    'cacheId': 'cElLiMk8T9MJ',
#    'formattedUrl': 'https://en.wikipedia.org/wiki/Elon_Musk',
#    'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Elon</b>_<b>Musk</b>',
#    'pagemap': {'hcard': [{'bday': '1971-06-28',
#       'fn': 'Elon Musk',
#       'nickname': 'Elon Reeve Musk',
#       'title': '.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-b...'}],
#     'person': [{'role': '.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-b...'}],
#     'metatags': [{'referrer': 'origin',
#       'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/34/Elon_Musk_Royal_Society_%28crop2%29.jpg/1200px-Elon_Musk_Royal_Society_%28crop2%29.jpg',
#       'theme-color': '#eaecf0',
#       'og:image:width': '1200',
#       'og:type': 'website',
#       'viewport': 'width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.25, maximum-scale=5.0',
#       'og:title': 'Elon Musk - Wikipedia',
#       'og:image:height': '1590',
#       'format-detection': 'telephone=no'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Elon Musk has taken control of Twitter and fired its top executives ...',
#    'htmlTitle': '<b>Elon Musk</b> has taken control of <b>Twitter</b> and fired its top executives ...',
#    'link': 'https://www.cnn.com/2022/10/27/tech/elon-musk-twitter/index.html',
#    'displayLink': 'www.cnn.com',
#    'snippet': 'Oct 28, 2022 ... Elon Musk has completed his $44 billion deal to buy Twitter, a source familiar with the deal told CNN ... Elon Musk just bought Twitter.',
#    'htmlSnippet': 'Oct 28, 2022 <b>...</b> <b>Elon Musk</b> has completed his $44 billion deal to buy <b>Twitter</b>, a source familiar with the deal told CNN ... <b>Elon Musk</b> just <b>bought Twitter</b>.',
#    'formattedUrl': 'https://www.cnn.com/2022/10/27/tech/elon-musk-twitter/index.html',
#    'htmlFormattedUrl': 'https://www.cnn.com/2022/10/27/tech/<b>elon</b>-<b>musk</b>-<b>twitter</b>/index.html',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRotIied_AG5t650tqvNxi6Yyk7rfVUwbhYgYvZtlBmtqvKsZfOCibKdZ4',
#       'width': '300',
#       'height': '168'}],
#     'metatags': [{'og:image': 'https://media.cnn.com/api/v1/images/stellar/prod/221027200356-elon-musk-twitter-pba.jpg?c=16x9&q=w_800,c_fill',
#       'twitter:title': 'Elon Musk has taken control of Twitter and fired its top executives | CNN Business',
#       'og:type': 'article',
#       'twitter:card': 'summary_large_image',
#       'article:published_time': '2022-10-28T01:00:00Z',
#       'og:site_name': 'CNN',
#       'author': "Donie O'Sullivan,Clare Duffy",
#       'og:title': 'Elon Musk has taken control of Twitter and fired its top executives | CNN Business',
#       'meta-section': 'business',
#       'type': 'article',
#       'og:description': 'Elon Musk has completed his $44 billion deal to buy Twitter, a source familiar with the deal told CNN Thursday, putting the world’s richest man in charge of one of the world’s most influential social media platforms.',
#       'twitter:image': 'https://media.cnn.com/api/v1/images/stellar/prod/221027200356-elon-musk-twitter-pba.jpg?c=16x9&q=w_800,c_fill',
#       'article:publisher': 'https://www.facebook.com/CNN',
#       'article:tag': 'business figures, companies, elon musk, internet and www, social media, technology, twitter',
#       'fb:app_id': '80401312489',
#       'twitter:site': '@CNNbusiness',
#       'article:modified_time': '2022-10-28T15:53:22Z',
#       'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no',
#       'twitter:description': 'Elon Musk has completed his $44 billion deal to buy Twitter, a source familiar with the deal told CNN Thursday, putting the world’s richest man in charge of one of the world’s most influential social media platforms.',
#       'template_type': 'article_leaf',
#       'theme': 'business',
#       'og:url': 'https://www.cnn.com/2022/10/27/tech/elon-musk-twitter/index.html'}],
#     'cse_image': [{'src': 'https://media.cnn.com/api/v1/images/stellar/prod/221027200356-elon-musk-twitter-pba.jpg?c=16x9&q=w_800,c_fill'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'What Elon Musk will likely do with Twitter if he buys it : NPR',
#    'htmlTitle': 'What <b>Elon Musk</b> will likely do with <b>Twitter</b> if he <b>buys</b> it : NPR',
#    'link': 'https://www.npr.org/2022/10/07/1127337447/heres-what-elon-musk-will-likely-do-with-twitter-if-he-buys-it',
#    'displayLink': 'www.npr.org',
#    'snippet': "Oct 7, 2022 ... Billionaire Elon Musk's on-again, off-again bid to acquire Twitter advanced this week after he agreed to pay the $44 billion he had\xa0...",
#    'htmlSnippet': 'Oct 7, 2022 <b>...</b> Billionaire <b>Elon Musk&#39;s</b> on-again, off-again bid to <b>acquire Twitter</b> advanced this week after he agreed to pay the $44 billion he had&nbsp;...',
#    'formattedUrl': 'https://www.npr.org/.../heres-what-elon-musk-will-likely-do-with-twitter-if- he-buys-it',
#    'htmlFormattedUrl': 'https://www.npr.org/.../heres-what-<b>elon</b>-<b>musk</b>-will-likely-do-with-<b>twitter</b>-if- he-buys-it',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSokQq7X-25wAeEeNdQq7NJetWD3Lg2S14NZudSBF0ul5yfvIAz3UhEhBU',
#       'width': '300',
#       'height': '168'}],
#     'speakablespecification': [{'cssselector': '[data-is-speakable]'}],
#     'metatags': [{'date': '2022-10-07',
#       'apple-itunes-app': 'app-id=324906251, app-argument=https://www.npr.org/2022/10/07/1127337447/heres-what-elon-musk-will-likely-do-with-twitter-if-he-buys-it',
#       'og:image': 'https://media.npr.org/assets/img/2022/10/06/gettyimages-1242720224_wide-75b421fe14303b8597732374bd131d94347eab68-s1400-c100.jpg',
#       'og:type': 'article',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': "Here's what Elon Musk will likely do with Twitter if he buys it",
#       'og:site_name': 'NPR',
#       'cxenseparse:pageclass': 'article',
#       'twitter:domain': 'npr.org',
#       'cxenseparse:publishtime': '2022-10-07T05:15:00-04:00',
#       'og:title': "Here's what Elon Musk will likely do with Twitter if he buys it",
#       'rating': 'General',
#       'og:description': "Musk says he'd loosen rules against spreading misinformation, allow former President Donald Trump back on Twitter, shake up the company's business model and find new revenue sources.",
#       'fb:pages': '10643211755',
#       'twitter:image:src': 'https://media.npr.org/assets/img/2022/10/06/gettyimages-1242720224_wide-75b421fe14303b8597732374bd131d94347eab68-s1400-c100.jpg',
#       'fb:app_id': '138837436154588',
#       'cxenseparse:author': 'Shannon Bond',
#       'twitter:site': '@NPR',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no',
#       'article:content_tier': 'free',
#       'og:url': 'https://www.npr.org/2022/10/07/1127337447/heres-what-elon-musk-will-likely-do-with-twitter-if-he-buys-it',
#       'article:opinion': 'false'}],
#     'cse_image': [{'src': 'https://media.npr.org/assets/img/2022/10/06/gettyimages-1242720224_wide-75b421fe14303b8597732374bd131d94347eab68-s1400-c100.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Elon Musk (@elonmusk) / Twitter',
#    'htmlTitle': '<b>Elon Musk</b> (@<b>elonmusk</b>) / <b>Twitter</b>',
#    'link': 'https://twitter.com/elonmusk',
#    'displayLink': 'twitter.com',
#    'snippet': "And on June 6, the Dragon 2 fleet's cumulative time in space surpassed the Space Shuttle fleet's time with 1,324 total days in orbit!",
#    'htmlSnippet': 'And on June 6, the Dragon 2 fleet&#39;s cumulative time in space surpassed the Space Shuttle fleet&#39;s time with 1,324 total days in orbit!',
#    'cacheId': 'QjQEmo2sFzcJ',
#    'formattedUrl': 'https://twitter.com/elonmusk',
#    'htmlFormattedUrl': 'https://<b>twitter</b>.com/<b>elonmusk</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTxINkihnQzrE6p8R1dOVc075aT41J_P4423EgT2sJ4N2aLL7Uaoiqf',
#       'width': '48',
#       'height': '48'}],
#     'imageobject': [{'contenturl': 'https://pbs.twimg.com/media/FyC70IWaUAIxnx8.jpg',
#       'width': '4096',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FyC70IWaUAIxnx8?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FyCXwYdWYBULeZW.jpg',
#       'width': '1133',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FyCXwYdWYBULeZW?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/Fx4woYFXwAI5JRC.jpg',
#       'width': '1538',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/Fx4woYFXwAI5JRC?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/Fx4wosjWcAA7rfz.jpg',
#       'width': '1024',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/Fx4wosjWcAA7rfz?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/Fx4wpG8XgAI20EH.jpg',
#       'width': '2048',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/Fx4wpG8XgAI20EH?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/Fx4L5JGWYAACpJX.jpg',
#       'width': '1170',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/Fx4L5JGWYAACpJX?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxyER7YaMAEm7iD.jpg',
#       'width': '3000',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxyER7YaMAEm7iD?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxyESMoaQAIwGK7.jpg',
#       'width': '3000',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxyESMoaQAIwGK7?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxyEStXaIAEkzqZ.jpg',
#       'width': '3000',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxyEStXaIAEkzqZ?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxwPBq4XoAAzF6p.jpg',
#       'width': '835',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxwPBq4XoAAzF6p?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuG_TZaEAANyli.jpg',
#       'width': '4000',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuG_TZaEAANyli?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuHB3fakAAxDPa.jpg',
#       'width': '1976',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuHB3fakAAxDPa?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuHHqyagAAAEQg.jpg',
#       'width': '2000',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuHHqyagAAAEQg?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuHQUcakAED7bj.jpg',
#       'width': '4000',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuHQUcakAED7bj?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuC39xX0AAd1tm.jpg',
#       'width': '2048',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuC39xX0AAd1tm?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuC39yWcAE7bkQ.jpg',
#       'width': '2048',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuC39yWcAE7bkQ?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuC39vWAAEiLUz.jpg',
#       'width': '2048',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuC39vWAAEiLUz?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxuMBnIWwAEl3S2.jpg',
#       'width': '899',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxuMBnIWwAEl3S2?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxsP0ngWIAI0D0P.jpg',
#       'width': '749',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxsP0ngWIAI0D0P?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxpIRJkWwAELy1m.jpg',
#       'width': '992',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxpIRJkWwAELy1m?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxpDVCQaMAAoAvt.jpg',
#       'width': '2732',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxpDVCQaMAAoAvt?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/Fxnhq-YXoAECTGT.jpg',
#       'width': '749',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/Fxnhq-YXoAECTGT?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/Fxnhq-XWwAI1UUe.jpg',
#       'width': '750',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/Fxnhq-XWwAI1UUe?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxfTjZRXsAITN2R.jpg',
#       'width': '1440',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxfTjZRXsAITN2R?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxfTj0TWIAAmdsM.jpg',
#       'width': '982',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxfTj0TWIAAmdsM?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxjjWHpX0AAqr11.jpg',
#       'width': '1280',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxjjWHpX0AAqr11?format=jpg&name=thumb'},
#      {'contenturl': 'https://pbs.twimg.com/media/FxjjWIGWIAQ9Ply.jpg',
#       'width': '1280',
#       'caption': 'Image',
#       'thumbnailurl': 'https://pbs.twimg.com/media/FxjjWIGWIAQ9Ply?format=jpg&name=thumb'}],
#     'person': [{'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1330170106501079041',
#       'givenname': 'Starlink',
#       'disambiguatingdescription': 'SpaceX',
#       'additionalname': 'Starlink'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '895332160130891776',
#       'givenname': 'Neuralink',
#       'additionalname': 'neuralink'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1451773004',
#       'givenname': 'International Space Station',
#       'disambiguatingdescription': 'NASA',
#       'additionalname': 'Space_Station'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1016059981907386368',
#       'givenname': 'Tesla Owners Silicon Valley',
#       'additionalname': 'teslaownersSV'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '13298072',
#       'givenname': 'Tesla',
#       'additionalname': 'Tesla'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '752567226',
#       'givenname': 'T(w)itter Daily News \uea00',
#       'additionalname': 'TitterDaily'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1346535293449428992',
#       'givenname': 'Tesla Charging',
#       'disambiguatingdescription': 'Tesla',
#       'additionalname': 'TeslaCharging'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '2530947115',
#       'givenname': 'Max Tegmark',
#       'additionalname': 'tegmark'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1330170106501079041',
#       'givenname': 'Starlink',
#       'disambiguatingdescription': 'SpaceX',
#       'additionalname': 'Starlink'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '243013409',
#       'givenname': 'Sawyer Merritt',
#       'additionalname': 'SawyerMerritt'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1330170106501079041',
#       'givenname': 'Starlink',
#       'disambiguatingdescription': 'SpaceX',
#       'additionalname': 'Starlink'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '34743251',
#       'givenname': 'SpaceX',
#       'additionalname': 'SpaceX'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '4914384040',
#       'givenname': 'The Babylon Bee',
#       'additionalname': 'TheBabylonBee'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'additionalname': 'elonmusk'},
#      {'identifier': '1118594454515003393',
#       'givenname': 'Dirty Tesla',
#       'additionalname': 'DirtyTesLa'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'},
#      {'identifier': '44196397',
#       'givenname': 'Elon Musk',
#       'disambiguatingdescription': 'Twitter',
#       'additionalname': 'elonmusk'}],
#     'interactioncounter': [{'userinteractioncount': '7851',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/SpaceX/status/1666538477805248512/likes'},
#      {'userinteractioncount': '924',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/SpaceX/status/1666538477805248512/retweets'},
#      {'userinteractioncount': '72',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/SpaceX/status/1666538477805248512/retweets/with_comments'},
#      {'userinteractioncount': '455',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/SpaceX/status/1666538477805248512'},
#      {'userinteractioncount': '32651',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1666498907986092046/likes'},
#      {'userinteractioncount': '5081',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1666498907986092046/retweets'},
#      {'userinteractioncount': '217',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1666498907986092046/retweets/with_comments'},
#      {'userinteractioncount': '2711',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1666498907986092046'},
#      {'userinteractioncount': '158531',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1666498723629654035/likes'},
#      {'userinteractioncount': '34255',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1666498723629654035/retweets'},
#      {'userinteractioncount': '2899',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1666498723629654035/retweets/with_comments'},
#      {'userinteractioncount': '12083',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1666498723629654035'},
#      {'userinteractioncount': '13881',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/Starlink/status/1666121550314233858/likes'},
#      {'userinteractioncount': '1476',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/Starlink/status/1666121550314233858/retweets'},
#      {'userinteractioncount': '89',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/Starlink/status/1666121550314233858/retweets/with_comments'},
#      {'userinteractioncount': '842',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/Starlink/status/1666121550314233858'},
#      {'userinteractioncount': '203311',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1666331961281900545/likes'},
#      {'userinteractioncount': '17409',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1666331961281900545/retweets'},
#      {'userinteractioncount': '2332',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1666331961281900545/retweets/with_comments'},
#      {'userinteractioncount': '11399',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1666331961281900545'},
#      {'userinteractioncount': '12232',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/neuralink/status/1666248950431760384/likes'},
#      {'userinteractioncount': '1469',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/neuralink/status/1666248950431760384/retweets'},
#      {'userinteractioncount': '102',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/neuralink/status/1666248950431760384/retweets/with_comments'},
#      {'userinteractioncount': '990',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/neuralink/status/1666248950431760384'},
#      {'userinteractioncount': '291605',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1666232126172176384/likes'},
#      {'userinteractioncount': '39816',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1666232126172176384/retweets'},
#      {'userinteractioncount': '2302',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1666232126172176384/retweets/with_comments'},
#      {'userinteractioncount': '23799',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1666232126172176384'},
#      {'userinteractioncount': '15695',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/Space_Station/status/1666023004579704832/likes'},
#      {'userinteractioncount': '2036',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/Space_Station/status/1666023004579704832/retweets'},
#      {'userinteractioncount': '95',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/Space_Station/status/1666023004579704832/retweets/with_comments'},
#      {'userinteractioncount': '918',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/Space_Station/status/1666023004579704832'},
#      {'userinteractioncount': '318621',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1665797367747026948/likes'},
#      {'userinteractioncount': '23434',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1665797367747026948/retweets'},
#      {'userinteractioncount': '9024',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1665797367747026948/retweets/with_comments'},
#      {'userinteractioncount': '57558',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1665797367747026948'},
#      {'userinteractioncount': '56243',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1665788623797600258/likes'},
#      {'userinteractioncount': '6596',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1665788623797600258/retweets'},
#      {'userinteractioncount': '284',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1665788623797600258/retweets/with_comments'},
#      {'userinteractioncount': '5155',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1665788623797600258'},
#      {'userinteractioncount': '62482',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1665784889008873476/likes'},
#      {'userinteractioncount': '11534',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1665784889008873476/retweets'},
#      {'userinteractioncount': '951',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1665784889008873476/retweets/with_comments'},
#      {'userinteractioncount': '7610',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1665784889008873476'},
#      {'userinteractioncount': '118574',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1665781992653291521/likes'},
#      {'userinteractioncount': '9891',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1665781992653291521/retweets'},
#      {'userinteractioncount': '577',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1665781992653291521/retweets/with_comments'},
#      {'userinteractioncount': '5009',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1665781992653291521'},
#      {'userinteractioncount': '9623',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/teslaownersSV/status/1665766361883369472/likes'},
#      {'userinteractioncount': '1058',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/teslaownersSV/status/1665766361883369472/retweets'},
#      {'userinteractioncount': '65',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/teslaownersSV/status/1665766361883369472/retweets/with_comments'},
#      {'userinteractioncount': '780',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/teslaownersSV/status/1665766361883369472'},
#      {'userinteractioncount': '15465',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/SpaceX/status/1665750439110017024/likes'},
#      {'userinteractioncount': '1901',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/SpaceX/status/1665750439110017024/retweets'},
#      {'userinteractioncount': '102',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/SpaceX/status/1665750439110017024/retweets/with_comments'},
#      {'userinteractioncount': '648',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/SpaceX/status/1665750439110017024'},
#      {'userinteractioncount': '20480',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/SpaceX/status/1665747395261632514/likes'},
#      {'userinteractioncount': '2616',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/SpaceX/status/1665747395261632514/retweets'},
#      {'userinteractioncount': '123',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/SpaceX/status/1665747395261632514/retweets/with_comments'},
#      {'userinteractioncount': '644',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/SpaceX/status/1665747395261632514'},
#      {'userinteractioncount': '10560',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/SpaceX/status/1665741594530832384/likes'},
#      {'userinteractioncount': '1667',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/SpaceX/status/1665741594530832384/retweets'},
#      {'userinteractioncount': '90',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/SpaceX/status/1665741594530832384/retweets/with_comments'},
#      {'userinteractioncount': '461',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/SpaceX/status/1665741594530832384'},
#      {'userinteractioncount': '19970',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/Tesla/status/1665068919109951489/likes'},
#      {'userinteractioncount': '2313',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/Tesla/status/1665068919109951489/retweets'},
#      {'userinteractioncount': '283',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/Tesla/status/1665068919109951489/retweets/with_comments'},
#      {'userinteractioncount': '1090',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/Tesla/status/1665068919109951489'},
#      {'userinteractioncount': '81159',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
#       'url': 'https://twitter.com/elonmusk/status/1665368017125900288/likes'},
#      {'userinteractioncount': '13776',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Retweets',
#       'url': 'https://twitter.com/elonmusk/status/1665368017125900288/retweets'},
#      {'userinteractioncount': '975',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Quotes',
#       'url': 'https://twitter.com/elonmusk/status/1665368017125900288/retweets/with_comments'},
#      {'userinteractioncount': '8142',
#       'interactiontype': 'https://schema.org/InteractAction',
#       'name': 'Replies',
#       'url': 'https://twitter.com/elonmusk/status/1665368017125900288'},
#      {'userinteractioncount': '10583',
#       'interactiontype': 'https://schema.org/LikeAction',
#       'name': 'Likes',
# ...
#       'datepublished': '2023-06-03T19:30:12.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1665078448816005122'},
#      {'identifier': '1664941886040076288',
#       'commentcount': '18646',
#       'position': '26',
#       'datecreated': '2023-06-03T10:27:33.000Z',
#       'datepublished': '2023-06-03T10:27:33.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664941886040076288'},
#      {'identifier': '1664843213344063488',
#       'position': '27',
#       'datecreated': '2023-06-03T03:55:28.000Z',
#       'datepublished': '2023-06-03T03:55:28.000Z'},
#      {'identifier': '1664830152193323008',
#       'commentcount': '620',
#       'articlebody': 'Dagan Shani has IMHO made the most important film of the year - about the harsh #AI truth:',
#       'datecreated': '2023-06-03T03:03:33.000Z',
#       'datepublished': '2023-06-03T03:03:33.000Z',
#       'url': 'https://twitter.com/tegmark/status/1664830152193323008'},
#      {'identifier': '1664796851978092545',
#       'position': '28',
#       'datecreated': '2023-06-03T00:51:14.000Z',
#       'datepublished': '2023-06-03T00:51:14.000Z'},
#      {'identifier': '1664758466177810432',
#       'commentcount': '871',
#       'articlebody': 'Starlink on Igloolik Island in the northern territory of Nunavut, Canada 🛰️🇨🇦',
#       'datecreated': '2023-06-02T22:18:42.000Z',
#       'isbasedon': 'https://twitter.com/qaatani9/status/1664292528655413250',
#       'datepublished': '2023-06-02T22:18:42.000Z',
#       'url': 'https://twitter.com/Starlink/status/1664758466177810432'},
#      {'identifier': '1664735019716288515',
#       'position': '29',
#       'datecreated': '2023-06-02T20:45:32.000Z',
#       'datepublished': '2023-06-02T20:45:32.000Z'},
#      {'identifier': '1664723258627817478',
#       'commentcount': '1519',
#       'articlebody': 'BREAKING: @Tesla says ALL new Model 3 vehicles in the US now qualify for the full $7,500 EV tax credit, meaning the Model 3 now starts at $32,740 (with incentives). In some states, you can...',
#       'datecreated': '2023-06-02T19:58:48.000Z',
#       'datepublished': '2023-06-02T19:58:48.000Z',
#       'url': 'https://twitter.com/SawyerMerritt/status/1664723258627817478'},
#      {'identifier': '1664728279293542401',
#       'position': '30',
#       'datecreated': '2023-06-02T20:18:45.000Z',
#       'datepublished': '2023-06-02T20:18:45.000Z'},
#      {'identifier': '1664717672104198147',
#       'commentcount': '924',
#       'articlebody': 'Starlink set an altitude and speed record for use in-flight during Starship’s first flight test, providing connectivity at 123,600+ feet and while traveling at Mach 1.7! 🛰️🚀',
#       'datecreated': '2023-06-02T19:36:36.000Z',
#       'datepublished': '2023-06-02T19:36:36.000Z',
#       'url': 'https://twitter.com/Starlink/status/1664717672104198147'},
#      {'identifier': '1664637044549726210',
#       'commentcount': '20110',
#       'articlebody': 'Let that sink in',
#       'position': '31',
#       'datecreated': '2023-06-02T14:16:13.000Z',
#       'datepublished': '2023-06-02T14:16:13.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664637044549726210'},
#      {'identifier': '1664627982638407687',
#       'commentcount': '30674',
#       'articlebody': 'X',
#       'position': '32',
#       'datecreated': '2023-06-02T13:40:13.000Z',
#       'datepublished': '2023-06-02T13:40:13.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664627982638407687'},
#      {'identifier': '1664614843297439744',
#       'commentcount': '9575',
#       'articlebody': 'Consenting adults should do whatever makes them happy, provided it does not harm others, but a child is not capable of consent, which is why we have laws protecting minors.',
#       'ispartof': 'https://twitter.com/elonmusk/status/1664609193230204929',
#       'position': '33',
#       'datecreated': '2023-06-02T12:48:00.000Z',
#       'datepublished': '2023-06-02T12:48:00.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664614843297439744'},
#      {'identifier': '1664611949517193219',
#       'position': '34',
#       'datecreated': '2023-06-02T12:36:30.000Z',
#       'datepublished': '2023-06-02T12:36:30.000Z'},
#      {'identifier': '1663944001224081408',
#       'commentcount': '1180',
#       'articlebody': 'Three years ago this week we launched our first human spaceflight mission to orbit. Thank you to @NASA, @inspiration4x, @Axiom_Space, and the 38 astronauts from all around the world for flying SpaceX!',
#       'datecreated': '2023-05-31T16:22:19.000Z',
#       'datepublished': '2023-05-31T16:22:19.000Z',
#       'url': 'https://twitter.com/SpaceX/status/1663944001224081408'},
#      {'identifier': '1664610007369875458',
#       'commentcount': '14829',
#       'articlebody': 'Insane',
#       'position': '35',
#       'datecreated': '2023-06-02T12:28:47.000Z',
#       'isbasedon': 'https://twitter.com/alx/status/1664609668927242241',
#       'datepublished': '2023-06-02T12:28:47.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664610007369875458'},
#      {'identifier': '1664609193230204929',
#       'commentcount': '28548',
#       'articlebody': 'Every parent should watch this',
#       'position': '36',
#       'datecreated': '2023-06-02T12:25:33.000Z',
#       'isbasedon': 'https://twitter.com/realDailyWire/status/1664424891372941312',
#       'datepublished': '2023-06-02T12:25:33.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664609193230204929'},
#      {'identifier': '1664519371551567879',
#       'position': '37',
#       'datecreated': '2023-06-02T06:28:38.000Z',
#       'datepublished': '2023-06-02T06:28:38.000Z'},
#      {'identifier': '1663663007984144386',
#       'commentcount': '906',
#       'articlebody': 'The Babylon Bee + @elonmusk at Twitter HQ TOMORROW. Premiering exclusively on Twitter.',
#       'datecreated': '2023-05-30T21:45:45.000Z',
#       'datepublished': '2023-05-30T21:45:45.000Z',
#       'url': 'https://twitter.com/TheBabylonBee/status/1663663007984144386'},
#      {'identifier': '1664387312057217028',
#       'position': '38',
#       'datecreated': '2023-06-01T21:43:52.000Z',
#       'datepublished': '2023-06-01T21:43:52.000Z'},
#      {'identifier': '1664031205430374402',
#       'commentcount': '691',
#       'articlebody': "Powerwall is one of the best products I've ever purchased. Nothing but sunny blue skies for over a week, yet power is out for 5k+ customers. Check out more details of my @Tesla Powerwall experience...",
#       'datecreated': '2023-05-31T22:08:50.000Z',
#       'datepublished': '2023-05-31T22:08:50.000Z',
#       'url': 'https://twitter.com/DirtyTesLa/status/1664031205430374402'},
#      {'identifier': '1664330279257767936',
#       'commentcount': '23669',
#       'articlebody': 'Lil X just asked if there are police cats, since there are police dogs 😂',
#       'position': '39',
#       'datecreated': '2023-06-01T17:57:14.000Z',
#       'datepublished': '2023-06-01T17:57:14.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664330279257767936'},
#      {'identifier': '1664330035530964996',
#       'commentcount': '6892',
#       'articlebody': 'Congratulations to Giga Shanghai & Tesla China SDS teams for their excellent work overcoming many obstacles over many years!!',
#       'position': '40',
#       'datecreated': '2023-06-01T17:56:16.000Z',
#       'datepublished': '2023-06-01T17:56:16.000Z',
#       'url': 'https://twitter.com/elonmusk/status/1664330035530964996'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Elon Musk bought Twitter. Here's what he says he'll do next : NPR",
#    'htmlTitle': '<b>Elon Musk bought Twitter</b>. Here&#39;s what he says he&#39;ll do next : NPR',
#    'link': 'https://www.npr.org/2022/04/25/1094671225/elon-musk-bought-twitter-plans',
#    'displayLink': 'www.npr.org',
#    'snippet': "Apr 25, 2022 ... Twitter on Monday announced it has accepted billionaire Elon Musk's bid to takeover the social media company for $44 billion.",
#    'htmlSnippet': 'Apr 25, 2022 <b>...</b> <b>Twitter</b> on Monday announced it has accepted billionaire <b>Elon Musk&#39;s</b> bid to takeover the social media company for $44 billion.',
#    'formattedUrl': 'https://www.npr.org/2022/04/25/.../elon-musk-bought-twitter-plans',
#    'htmlFormattedUrl': 'https://www.npr.org/2022/04/25/.../<b>elon</b>-<b>musk</b>-<b>bought</b>-<b>twitter</b>-plans',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTsvWCK6MO2StkfozFCqPmIMXE-__E9wEXSMGZZAeJaYte_CVrs_4DRsl3O',
#       'width': '300',
#       'height': '168'}],
#     'speakablespecification': [{'cssselector': '[data-is-speakable]'}],
#     'metatags': [{'date': '2022-04-25',
#       'apple-itunes-app': 'app-id=324906251, app-argument=https://www.npr.org/2022/04/25/1094671225/elon-musk-bought-twitter-plans',
#       'og:image': 'https://media.npr.org/assets/img/2022/04/25/ap22101192217431-1-_wide-9883d163553e0ec534ba21faa3872914b24a472b-s1400-c100.jpg',
#       'og:type': 'article',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': "Elon Musk bought Twitter. Here's what he says he'll do next",
#       'og:site_name': 'NPR',
#       'cxenseparse:pageclass': 'article',
#       'twitter:domain': 'npr.org',
#       'cxenseparse:publishtime': '2022-04-25T18:28:34-04:00',
#       'og:title': "Elon Musk bought Twitter. Here's what he says he'll do next",
#       'rating': 'General',
#       'og:description': "Before Twitter accepted Musk's $44 billion offer, he has floated numerous ideas for changing the social network. Not all of those proposals have been welcomed by experts.",
#       'fb:pages': '10643211755',
#       'twitter:image:src': 'https://media.npr.org/assets/img/2022/04/25/ap22101192217431-1-_wide-9883d163553e0ec534ba21faa3872914b24a472b-s1400-c100.jpg',
#       'fb:app_id': '138837436154588',
#       'cxenseparse:author': 'Bobby Allyn',
#       'twitter:site': '@NPR',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no',
#       'article:content_tier': 'free',
#       'og:url': 'https://www.npr.org/2022/04/25/1094671225/elon-musk-bought-twitter-plans',
#       'article:opinion': 'false'}],
#     'cse_image': [{'src': 'https://media.npr.org/assets/img/2022/04/25/ap22101192217431-1-_wide-9883d163553e0ec534ba21faa3872914b24a472b-s1400-c100.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Elon Musk says he's found a new CEO to lead Twitter | PBS NewsHour",
#    'htmlTitle': '<b>Elon Musk</b> says he&#39;s found a new CEO to lead <b>Twitter</b> | PBS NewsHour',
#    'link': 'https://www.pbs.org/newshour/economy/elon-musk-says-hes-found-a-woman-to-lead-twitter-as-new-ceo',
#    'displayLink': 'www.pbs.org',
#    'snippet': 'May 11, 2023 ... SpaceX owner and Tesla CEO Elon Musk speaks during a conversation with ... Musk, who bought Twitter last fall and has been running it since,\xa0...',
#    'htmlSnippet': 'May 11, 2023 <b>...</b> SpaceX owner and Tesla CEO <b>Elon Musk</b> speaks during a conversation with ... Musk, who <b>bought Twitter</b> last fall and has been running it since,&nbsp;...',
#    'cacheId': '59YqypckFV8J',
#    'formattedUrl': 'https://www.pbs.org/.../elon-musk-says-hes-found-a-woman-to-lead-twitter-as -new-ceo',
#    'htmlFormattedUrl': 'https://www.pbs.org/.../<b>elon</b>-<b>musk</b>-says-hes-found-a-woman-to-lead-<b>twitter</b>-as -new-ceo',
#    'pagemap': {'hcard': [{'fn': 'Barbara Ortutay, Associated Press'},
#      {'fn': "Matt O'Brien, Associated Press"}],
#     'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSePcLr-cnmmi36m9I8dbeRN_d5xSlToMEcwKpv5KSTIRtEUtxsokmj_8G7',
#       'width': '275',
#       'height': '183'}],
#     'newsmediaorganization': [{'name': 'PBS NewsHour'}],
#     'imageobject': [{'width': '600',
#       'url': 'https://d3i6fh83elv35t.cloudfront.net/static/assets/images/logo-600x60.png',
#       'height': '60'}],
#     'person': [{'name': 'Barbara Ortutay, Associated Press'},
#      {'name': "Matt O'Brien, Associated Press"},
#      {'name': 'Barbara Ortutay, Associated Press'},
#      {'name': "Matt O'Brien, Associated Press"}],
#     'metatags': [{'og:image': 'https://d3i6fh83elv35t.cloudfront.net/static/2022/02/newswrapmusk-1024x683.jpg',
#       'msapplication-config': 'https://d3i6fh83elv35t.cloudfront.net/static/assets/images/favicon/browserconfig.xml',
#       'og:type': 'article',
#       'og:image:width': '1024',
#       'article:published_time': '2023-05-11T20:12:24-04:00',
#       'article:section': 'Economy',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': "Elon Musk says he's found a new CEO to lead Twitter",
#       'theme-color': '#ffffff',
#       'og:site_name': 'PBS NewsHour',
#       'og:title': "Elon Musk says he's found a new CEO to lead Twitter",
#       'og:image:height': '683',
#       'og:description': "The Tesla billionaire said in a tweet Thursday that his role will transition to being Twitter's executive chairman and chief technology officer.",
#       'fb:pages': '6491828674',
#       'article:publisher': 'https://www.facebook.com/newshour/',
#       'twitter:image': 'https://d3i6fh83elv35t.cloudfront.net/static/2022/02/newswrapmusk-1024x683.jpg',
#       'article:tag': 'ceo, elon musk, twitter',
#       'fb:app_id': '114150878604116',
#       'twitter:site': '@newshour',
#       'viewport': 'width=device-width, initial-scale=1',
#       'news_keywords': 'ceo, elon musk, twitter, economy',
#       'twitter:description': "The Tesla billionaire said in a tweet Thursday that his role will transition to being Twitter's executive chairman and chief technology officer.",
#       'og:locale': 'en_US',
#       'og:url': 'https://www.pbs.org/newshour/economy/elon-musk-says-hes-found-a-woman-to-lead-twitter-as-new-ceo'}],
#     'cse_image': [{'src': 'https://d3i6fh83elv35t.cloudfront.net/static/2022/02/newswrapmusk-1024x683.jpg'}],
#     'newsarticle': [{'image': 'https://d3i6fh83elv35t.cloudfront.net/static/2022/02/newswrapmusk-1024x683.jpg',
#       'articlebody': 'Elon Musk said Thursday he has found a new CEO for Twitter, or X Corp. as it’s now called — and it’s a woman. He did not name her but said she will be starting in about six weeks. Musk,...',
#       'datemodified': '2023-05-12T08:59:00-04:00',
#       'articlesection': 'Economy',
#       'headline': 'Elon Musk says he’s found a new CEO to lead Twitter',
#       'datepublished': '2023-05-11T20:12:24-04:00',
#       'thumbnailurl': 'https://d3i6fh83elv35t.cloudfront.net/static/2022/02/newswrapmusk-1024x683.jpg',
#       'mainentityofpage': 'true'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'About Twitter Blue',
#    'htmlTitle': 'About <b>Twitter</b> Blue',
#    'link': 'https://help.twitter.com/en/using-twitter/twitter-blue',
#    'displayLink': 'help.twitter.com',
#    'snippet': 'Prioritized rankings in conversations and search: Tweets that you interact with ... Longer Tweets allow Blue subscribers to Tweet up to 10,000 characters.',
#    'htmlSnippet': 'Prioritized rankings in conversations and <b>search</b>: <b>Tweets</b> that you interact with ... Longer <b>Tweets</b> allow Blue subscribers to <b>Tweet</b> up to 10,000 characters.',
#    'cacheId': 'YL6dLlBAmgYJ',
#    'formattedUrl': 'https://help.twitter.com/en/using-twitter/twitter-blue',
#    'htmlFormattedUrl': 'https://help.<b>twitter</b>.com/en/using-<b>twitter</b>/<b>twitter</b>-blue',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQqNlY7ZmB1WfPB9SoGKvT70j0_HMvmwhnZOCai0SOQPW9-4NC8Q7eBnoQ',
#       'width': '310',
#       'height': '162'}],
#     'metatags': [{'og:image': 'https://cdn.cms-twdigitalassets.com/content/dam/help-twitter/logos/htc-summary-card.jpg.twimg.768.jpg',
#       'og:type': 'article',
#       'twitter:card': 'summary',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:widgets:csp': 'on',
#       'og:title': 'About Twitter Blue',
#       'twitter:widgets:new-embed-design': 'on',
#       'og:url': 'https://help.twitter.com/en/using-twitter/twitter-blue',
#       'og:description': 'Learn about our monthly subscription service offering exclusive access to premium features.'}],
#     'cse_image': [{'src': 'https://cdn.cms-twdigitalassets.com/content/dam/help-twitter/logos/htc-summary-card.jpg.twimg.768.jpg'}]}}]}

# %% [markdown]
# #### Langchain GoogleSearchAPIWrapper

# %%
from langchain.utilities import GoogleSearchAPIWrapper

google_search = GoogleSearchAPIWrapper(
    k = 10,
    siterestrict = False
)

# %%
# This place is really low robustness, need to dig down
search_result = google_search.results(query_c, 10)

# %%
print(search_result)
# Out:
# [{'title': 'Acquisition of Twitter by Elon Musk - Wikipedia', 'link': 'https://en.wikipedia.org/wiki/Acquisition_of_Twitter_by_Elon_Musk', 'snippet': 'Musk had begun buying shares of the company in January 2022, becoming its largest shareholder by April with a 9.1 percent ownership stake. Twitter invited\xa0...'}, {'title': "Hate Speech's Rise on Twitter Under Elon Musk Is Unprecedented ...", 'link': 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html', 'snippet': "Dec 2, 2022 ... Hate Speech's Rise on Twitter Is Unprecedented, Researchers Find ... Before Elon Musk bought Twitter, slurs against Black Americans showed\xa0..."}, {'title': 'Why Elon Musk Bought Twitter | The New Yorker', 'link': 'https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter', 'snippet': "Apr 26, 2022 ... Why do you think Elon Musk is buying Twitter? I assume it's because he has some genuine set of political and social beliefs about how Twitter\xa0..."}, {'title': 'Elon Musk - Wikipedia', 'link': 'https://en.wikipedia.org/wiki/Elon_Musk', 'snippet': 'Elon Reeve Musk is a business magnate and investor. He is the founder, CEO and chief ... Musk expressed interest in buying Twitter as early as 2017,\xa0...'}, {'title': 'Elon Musk has taken control of Twitter and fired its top executives ...', 'link': 'https://www.cnn.com/2022/10/27/tech/elon-musk-twitter/index.html', 'snippet': 'Oct 28, 2022 ... Elon Musk has completed his $44 billion deal to buy Twitter, a source familiar with the deal told CNN ... Elon Musk just bought Twitter.'}, {'title': 'What Elon Musk will likely do with Twitter if he buys it : NPR', 'link': 'https://www.npr.org/2022/10/07/1127337447/heres-what-elon-musk-will-likely-do-with-twitter-if-he-buys-it', 'snippet': "Oct 7, 2022 ... Billionaire Elon Musk's on-again, off-again bid to acquire Twitter advanced this week after he agreed to pay the $44 billion he had\xa0..."}, {'title': 'Elon Musk (@elonmusk) / Twitter', 'link': 'https://twitter.com/elonmusk', 'snippet': "And on June 6, the Dragon 2 fleet's cumulative time in space surpassed the Space Shuttle fleet's time with 1,324 total days in orbit!"}, {'title': "Elon Musk bought Twitter. Here's what he says he'll do next : NPR", 'link': 'https://www.npr.org/2022/04/25/1094671225/elon-musk-bought-twitter-plans', 'snippet': "Apr 25, 2022 ... Twitter on Monday announced it has accepted billionaire Elon Musk's bid to takeover the social media company for $44 billion."}, {'title': "Elon Musk says he's found a new CEO to lead Twitter | PBS NewsHour", 'link': 'https://www.pbs.org/newshour/economy/elon-musk-says-hes-found-a-woman-to-lead-twitter-as-new-ceo', 'snippet': 'May 11, 2023 ... SpaceX owner and Tesla CEO Elon Musk speaks during a conversation with ... Musk, who bought Twitter last fall and has been running it since,\xa0...'}, {'title': 'About Twitter Blue', 'link': 'https://help.twitter.com/en/using-twitter/twitter-blue', 'snippet': 'Prioritized rankings in conversations and search: Tweets that you interact with ... Longer Tweets allow Blue subscribers to Tweet up to 10,000 characters.'}]

# %%
i = 0
for sr in search_result:
    print(i,' ', sr['link'])
    i += 1
# Out:
# 0   https://en.wikipedia.org/wiki/Acquisition_of_Twitter_by_Elon_Musk
# 1   https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html
# 2   https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter
# 3   https://en.wikipedia.org/wiki/Elon_Musk
# 4   https://www.cnn.com/2022/10/27/tech/elon-musk-twitter/index.html
# 5   https://www.npr.org/2022/10/07/1127337447/heres-what-elon-musk-will-likely-do-with-twitter-if-he-buys-it
# 6   https://twitter.com/elonmusk
# 7   https://www.npr.org/2022/04/25/1094671225/elon-musk-bought-twitter-plans
# 8   https://www.pbs.org/newshour/economy/elon-musk-says-hes-found-a-woman-to-lead-twitter-as-new-ceo
# 9   https://help.twitter.com/en/using-twitter/twitter-blue

# %%
i = 0
for sr in search_result:
    print(i,' ', sr['title'])
    i += 1
# Out:
# 0   Acquisition of Twitter by Elon Musk - Wikipedia
# 1   Hate Speech's Rise on Twitter Under Elon Musk Is Unprecedented ...
# 2   Why Elon Musk Bought Twitter | The New Yorker
# 3   Elon Musk - Wikipedia
# 4   Elon Musk has taken control of Twitter and fired its top executives ...
# 5   What Elon Musk will likely do with Twitter if he buys it : NPR
# 6   Elon Musk (@elonmusk) / Twitter
# 7   Elon Musk bought Twitter. Here's what he says he'll do next : NPR
# 8   Elon Musk says he's found a new CEO to lead Twitter | PBS NewsHour
# 9   About Twitter Blue

# %%
i = 0
for sr in search_result:
    print(i,' ', sr['snippet'])
    i += 1
# Out:
# 0   Musk had begun buying shares of the company in January 2022, becoming its largest shareholder by April with a 9.1 percent ownership stake. Twitter invited ...
# 1   Dec 2, 2022 ... Hate Speech's Rise on Twitter Is Unprecedented, Researchers Find ... Before Elon Musk bought Twitter, slurs against Black Americans showed ...
# 2   Apr 26, 2022 ... Why do you think Elon Musk is buying Twitter? I assume it's because he has some genuine set of political and social beliefs about how Twitter ...
# 3   Elon Reeve Musk is a business magnate and investor. He is the founder, CEO and chief ... Musk expressed interest in buying Twitter as early as 2017, ...
# 4   Oct 28, 2022 ... Elon Musk has completed his $44 billion deal to buy Twitter, a source familiar with the deal told CNN ... Elon Musk just bought Twitter.
# 5   Oct 7, 2022 ... Billionaire Elon Musk's on-again, off-again bid to acquire Twitter advanced this week after he agreed to pay the $44 billion he had ...
# 6   And on June 6, the Dragon 2 fleet's cumulative time in space surpassed the Space Shuttle fleet's time with 1,324 total days in orbit!
# 7   Apr 25, 2022 ... Twitter on Monday announced it has accepted billionaire Elon Musk's bid to takeover the social media company for $44 billion.
# 8   May 11, 2023 ... SpaceX owner and Tesla CEO Elon Musk speaks during a conversation with ... Musk, who bought Twitter last fall and has been running it since, ...
# 9   Prioritized rankings in conversations and search: Tweets that you interact with ... Longer Tweets allow Blue subscribers to Tweet up to 10,000 characters.

# %% [markdown]
# ## 3. Text Processing
# - I/O
#     - Input: {"Link", "Title", "Snippet"}
#     - Output: Text String

# %% [markdown]
# ### 3.1. To Recommend Algorithm
# - Performance
#     - Runtime: Almost 0s
#
# - Problem

# %% [markdown]
# #### Without Filter and Construct Text
# - Structure: {Link Index} - {Title} - {Snippet}

# %%
# Construct Text to Recommend Algorithm
i = 0
text_to_ra = query + '\n'
for sr in search_result:
    text_to_ra += ' - '.join([
        'source: ' + f'url{i}', 
        'title: ' + sr['title'], 
        'snippet:' + sr['snippet']
    ]) + '\n'
    i += 1
print(text_to_ra)
# Out:
# Why Elon Musk bought twitter?
# source: url0 - title: Acquisition of Twitter by Elon Musk - Wikipedia - snippet:Musk had begun buying shares of the company in January 2022, becoming its largest shareholder by April with a 9.1 percent ownership stake. Twitter invited ...
# source: url1 - title: Hate Speech's Rise on Twitter Under Elon Musk Is Unprecedented ... - snippet:Dec 2, 2022 ... Hate Speech's Rise on Twitter Is Unprecedented, Researchers Find ... Before Elon Musk bought Twitter, slurs against Black Americans showed ...
# source: url2 - title: Why Elon Musk Bought Twitter | The New Yorker - snippet:Apr 26, 2022 ... Why do you think Elon Musk is buying Twitter? I assume it's because he has some genuine set of political and social beliefs about how Twitter ...
# source: url3 - title: Elon Musk - Wikipedia - snippet:Elon Reeve Musk is a business magnate and investor. He is the founder, CEO and chief ... Musk expressed interest in buying Twitter as early as 2017, ...
# source: url4 - title: Elon Musk has taken control of Twitter and fired its top executives ... - snippet:Oct 28, 2022 ... Elon Musk has completed his $44 billion deal to buy Twitter, a source familiar with the deal told CNN ... Elon Musk just bought Twitter.
# source: url5 - title: What Elon Musk will likely do with Twitter if he buys it : NPR - snippet:Oct 7, 2022 ... Billionaire Elon Musk's on-again, off-again bid to acquire Twitter advanced this week after he agreed to pay the $44 billion he had ...
# source: url6 - title: Elon Musk (@elonmusk) / Twitter - snippet:And on June 6, the Dragon 2 fleet's cumulative time in space surpassed the Space Shuttle fleet's time with 1,324 total days in orbit!
# source: url7 - title: Elon Musk bought Twitter. Here's what he says he'll do next : NPR - snippet:Apr 25, 2022 ... Twitter on Monday announced it has accepted billionaire Elon Musk's bid to takeover the social media company for $44 billion.
# source: url8 - title: Elon Musk says he's found a new CEO to lead Twitter | PBS NewsHour - snippet:May 11, 2023 ... SpaceX owner and Tesla CEO Elon Musk speaks during a conversation with ... Musk, who bought Twitter last fall and has been running it since, ...
# source: url9 - title: About Twitter Blue - snippet:Prioritized rankings in conversations and search: Tweets that you interact with ... Longer Tweets allow Blue subscribers to Tweet up to 10,000 characters.

# %%
# Save the Text to .txt
with open('text_to_ra.txt', 'w') as f:
    f.write(text_to_ra)

# %% [markdown]
# ### 3.2 To Understanding Synthesis Algorithm
# - Problem:
#     - Filtering the text gather from web (Langchain would be more serious)

# %% [markdown]
# #### Web filtering with Top-K Method
# - Description
#     - Directly select the top k result return from Google CSE
#     - Load the Web Link and Get the Text String

# %%
i = 0
for sr in search_result:
    print(i,' ', sr['link'])
    i += 1
# Out:
# 0   https://en.wikipedia.org/wiki/Acquisition_of_Twitter_by_Elon_Musk
# 1   https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html
# 2   https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter
# 3   https://en.wikipedia.org/wiki/Elon_Musk
# 4   https://www.cnn.com/2022/10/27/tech/elon-musk-twitter/index.html
# 5   https://www.npr.org/2022/10/07/1127337447/heres-what-elon-musk-will-likely-do-with-twitter-if-he-buys-it
# 6   https://twitter.com/elonmusk
# 7   https://www.npr.org/2022/04/25/1094671225/elon-musk-bought-twitter-plans
# 8   https://www.pbs.org/newshour/economy/elon-musk-says-hes-found-a-woman-to-lead-twitter-as-new-ceo
# 9   https://help.twitter.com/en/using-twitter/twitter-blue

# %%
# Top k Method
k = 3
web_url = []

for i in range(k):
    web_url.append(search_result[i]['link'])

print(web_url)
# Out:
# ['https://en.wikipedia.org/wiki/Acquisition_of_Twitter_by_Elon_Musk', 'https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html', 'https://www.newyorker.com/news/q-and-a/why-elon-musk-bought-twitter']

# %% [markdown]
# #### Read with Requests + bs4

# %%
import requests
from bs4 import BeautifulSoup

def get_text_content_from_link(url):
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the desired elements and extract their text content
        text_content = ''
        for element in soup.find_all('p'):  # Example: Extract text from all <p> tags
            text_content += element.get_text() + '\n'

        return text_content

    else:
        print(f"Failed to retrieve content from {url}. Status code: {response.status_code}")
        return None

# %%
text_to_su = ''
for i in range(len(web_url)):
    try:
        web_content = get_text_content_from_link(web_url[i])
        lines = web_content.split('\n')
        for line in lines:
            if len(line) > 100:
                web_content += line + '\n'
        text_to_su += ''.join(['\n',f'[this text is from url{i}]', '\n', web_content])
        print(i)
    except:
        pass
# Out:
# 0
# Failed to retrieve content from https://www.nytimes.com/2022/12/02/technology/twitter-hate-speech.html. Status code: 403
# 2

# %%
with open('text_to_su.txt', 'w') as f:
    f.write(text_to_su)

# print(text_to_su)

# %% [markdown]
# #### Read with Langchain-Unstructured

# %%
from langchain.document_loaders import UnstructuredURLLoader

url_loader = UnstructuredURLLoader(
    urls = web_url,
    continue_on_failure = True,  # determines whether the loader should continue loading files even if there is a failure
    mode = "single"  # determines whether the loader should return a single document or a list of documents
)

url_data = url_loader.load()

# %%
text_to_su = ''

for i in range(len(url_data)):
    try:
        text = url_data[i].page_content
        lines = text.split('\n')
        for line in lines:
            if (len(line) > 100):
                text += line + '\n'
        text_to_su += ''.join(['\n',f'[this text is from url{i}]', '\n', text])
        print(i)
    except:
        pass
# Out:
# 0
# 1
# 2

# %%
with open('text_to_su.txt', 'w') as f:
    f.write(text_to_su)

# print(text_to_su)
